# %%
import pandas as ps
from sklearn import linear_model
import matplotlib.pyplot as plt
# Out:
# C:\Users\Mohd Afzal\AppData\Local\Temp\ipykernel_10276\2898601830.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as ps

# %%
df = ps.read_csv('data.csv')
df
# Out:
#   area   price
# 0   a1  550000
# 1   a2  565000
# 2   a3  610000
# 3   a4  680000
# 4   a5  725000

# %%
# %matplotlib inline
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(df.area,df.price,color='green',marker='.')

# %%
# %matplotlib inline
plt.xlabel('area')
plt.ylabel('price')
plt.bar(df.area,df.price,color='green',width=.4)
# Out:
# <BarContainer object of 5 artists>

# %%
# %matplotlib inline
plt.xlabel('area')
plt.ylabel('price')
plt.barh(df.area,df.price,color='green')
# Out:
# <BarContainer object of 5 artists>

# %%
# %matplotlib inline
import numpy as np
y=np()
x=np(   )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
#       2 import numpy as np
# ----> 3 y=np()
#       4 x=np(   )
#
# TypeError: 'module' object is not callable

# %%
dk = ps.read_csv('loan.csv')
dk
# Out:
#    debt     year
# 0    23  2009-10
# 1    21  2010-11
# 2    41  2011-12
# 3    54  2012-13
# 4   123  2013-14
# 5   444  2014-15

# %%
# %matplotlib inline
plt.xlabel('loan')
plt.ylabel('year')
# for i, (xi, yi) in enumerate(zip(x, y)):
#     plt.annotate(f'({xi}, {yi})', (xi, yi), textcoords="offset points", xytext=(-10,10), ha='center')

plt.plot(dk.year,dk.debt,color='green')
plt.xticks
# Out:
# <function matplotlib.pyplot.xticks(ticks: 'ArrayLike | None' = None, labels: 'Sequence[str] | None' = None, *, minor: 'bool' = False, **kwargs) -> 'tuple[list[Tick] | np.ndarray, list[Text]]'>

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

plt.plot(x, y, marker='o', linestyle='-')

for i, (xi, yi) in enumerate(zip(x, y)):
    plt.annotate(f'({xi}, {yi})', (xi, yi), textcoords="offset points", xytext=(-10,10), ha='center')

plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Line Graph with Values')
plt.grid(True)
plt.show()

# %%
df = ps.read_csv('taxRate.csv')
df
# Out:
#   taxIncome  taxRate
# 0     2.5-5        5
# 1     5-7.5       10
# 2    7.5-10       15
# 3   10-12.5       20
# 4   12.5-15       25

# %%
plt.figure(figsize=(8, 8))
plt.pie(df['taxRate'], labels=df['taxIncome'], autopct='%1.1f%%', startangle=140)
plt.title('Tax Rate Distribution')
plt.axis('equal')
plt.show()

# %%
df['income_min'] = df['taxIncome'].apply(lambda x: float(x.split('-')[0]))
df['income_max'] = df['taxIncome'].apply(lambda x: float(x.split('-')[1]))
plt.hist(df['income_min'], bins=5, weights=df['taxRate']b, color='blue')
plt.xlabel('Tax Income')
plt.ylabel('Tax Rate (%)')
plt.title('Tax Rate vs Tax Income')
plt.show()

# %%
df = ps.read_csv('freq.csv')
df
# Out:
#       CI  Frequency
# 0  10-20          5
# 1  20-30         12
# 2  30-40         14
# 3  40-50         25
# 4  50-60         14
# 5  60-70          3

# %%
intervals = df['CI']
frequencies = df['Frequency']
midpoints = [(int(interval.split('-')[0]) + int(interval.split('-')[1])) / 2 for interval in intervals]
plt.plot(midpoints, frequencies)
plt.title('Frequency Polygon')
plt.xlabel('CI')
plt.ylabel('Frequency')
plt.show()
